# %%
from google.colab import userdata

TOKEN = userdata.get('GITHUB_TOKEN')

USERNAME = "Muhammad-Huzzaifa"
REPO_NAME = "urdu-question-generation"

REPO_URL = f"https://{USERNAME}:{TOKEN}@github.com/{USERNAME}/{REPO_NAME}.git"

# %%
# !git clone {REPO_URL}
# Out:
# Cloning into 'urdu-question-generation'...
# remote: Enumerating objects: 90, done.
# remote: Counting objects: 100% (90/90), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 90 (delta 37), reused 76 (delta 26), pack-reused 0 (from 0)
# Receiving objects: 100% (90/90), 230.71 KiB | 23.07 MiB/s, done.
# Resolving deltas: 100% (37/37), done.

# %%
# %cd {REPO_NAME}
# Out:
# /content/urdu-question-generation

# %%
# !git config --global user.email "huzzaaifa83@gmail.com"
# !git config --global user.name "Muhammad Huzaifa"

# %%
# !git pull origin main
# Out:
# From https://github.com/Muhammad-Huzzaifa/urdu-question-generation
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 1)) (4.8.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 2)) (0.2.2)
# Collecting sacrebleu (from -r requirements.txt (line 3))
#   Downloading sacrebleu-2.6.0-py3-none-any.whl.metadata (39 kB)
# Collecting rouge-score (from -r requirements.txt (line 4))
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 5)) (2.11.0+cu128)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 7)) (4.67.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from datasets->-r requirements.txt (line 1)) (3.32.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.13/dist-packages (from datasets->-r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.13/dist-packages (from datasets->-r requirements.txt (line 1)) (23.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from datasets->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from datasets->-r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.13/dist-packages (from datasets->-r requirements.txt (line 1)) (2.32.4)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.13/dist-packages (from datasets->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.13/dist-packages (from datasets->-r requirements.txt (line 1)) (4.0.1)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.13/dist-packages (from datasets->-r requirements.txt (line 1)) (0.70.19)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r requirements.txt (line 1)) (2025.12.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from datasets->-r requirements.txt (line 1)) (1.29.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from datasets->-r requirements.txt (line 1)) (26.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.13/dist-packages (from datasets->-r requirements.txt (line 1)) (6.0.3)
# Collecting portalocker (from sacrebleu->-r requirements.txt (line 3))
#   Downloading portalocker-4.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.13/dist-packages (from sacrebleu->-r requirements.txt (line 3)) (2025.11.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.13/dist-packages (from sacrebleu->-r requirements.txt (line 3)) (0.9.0)
# Collecting colorama (from sacrebleu->-r requirements.txt (line 3))
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.13/dist-packages (from sacrebleu->-r requirements.txt (line 3)) (6.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.13/dist-packages (from rouge-score->-r requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.13/dist-packages (from rouge-score->-r requirements.txt (line 4)) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.13/dist-packages (from rouge-score->-r requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 5)) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 5)) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 5)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 5)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 5)) (3.1.6)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 5)) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 5)) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 5)) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 5)) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 5)) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 5)) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 5)) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 5)) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 5)) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 5)) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 5)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 5)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 5)) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 5)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 5)) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r requirements.txt (line 5)) (12.8.90)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->-r requirements.txt (line 6)) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib->-r requirements.txt (line 6)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch->-r requirements.txt (line 5)) (1.8.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r requirements.txt (line 1)) (3.14.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets->-r requirements.txt (line 1)) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets->-r requirements.txt (line 1)) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets->-r requirements.txt (line 1)) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets->-r requirements.txt (line 1)) (8.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.32.2->datasets->-r requirements.txt (line 1)) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.32.2->datasets->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch->-r requirements.txt (line 5)) (3.0.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.13/dist-packages (from nltk->rouge-score->-r requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets->-r requirements.txt (line 1)) (2026.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r requirements.txt (line 1)) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r requirements.txt (line 1)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r requirements.txt (line 1)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r requirements.txt (line 1)) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r requirements.txt (line 1)) (1.24.5)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib->nltk->rouge-score->-r requirements.txt (line 4)) (3.1.2)
# Downloading sacrebleu-2.6.0-py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 1.2 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-4.3.0-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.6/129.6 kB 4.2 MB/s eta 0:00:00
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24986 sha256=52cdec56834b3fd49a8ba580a14654d63fa52db3cf22fcad692b7346210a23f6
#   Stored in directory: /root/.cache/pip/wheels/44/af/da/5ffc433e2786f0b1a9c6f458d5fb8f611d8eb332387f18698f
# Successfully built rouge-score
# Installing collected packages: portalocker, colorama, sacrebleu, rouge-score
# Successfully installed colorama-0.4.6 portalocker-4.3.0 rouge-score-0.1.2 sacrebleu-2.6.0

# %%
# !python -m scripts.prepare_data
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md: 100% 898/898 [00:00<00:00, 5.30MB/s]
#
# data/train-00000-of-00001-bac007e8ca7192(…): downloading bytes:  91% 27.4M/30.2M [00:01<00:00, 27.2MB/s, 1.15MB/s  ]
# data/train-00000-of-00001-bac007e8ca7192(…): downloading bytes: 100% 27.9M/27.9M [00:01<00:00, 17.9MB/s, 2.65MB/s  ]
# data/train-00000-of-00001-bac007e8ca7192(…): reconstructing file: 100% 30.2M/30.2M [00:01<00:00, 19.4MB/s, 2.90MB/s  ]
#
# data/validation-00000-of-00001-cf8a6960d(…): downloading bytes:   0% 0.00/2.92M [00:00<?, ?B/s]
# data/validation-00000-of-00001-cf8a6960d(…): downloading bytes: 100% 2.56M/2.56M [00:01<00:00, 2.09MB/s,  247kB/s  ]
# data/validation-00000-of-00001-cf8a6960d(…): reconstructing file: 100% 2.92M/2.92M [00:01<00:00, 2.40MB/s,  283kB/s  ]
# Generating train split: 100% 124745/124745 [00:00<00:00, 154305.63 examples/s]
# Generating validation split: 100% 16824/16824 [00:00<00:00, 163104.71 examples/s]
# README.md: 100% 489/489 [00:00<00:00, 2.43MB/s]
#
# data/train-00000-of-00001.parquet: downloading bytes:   0% 0.00/76.0k [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet: downloading bytes: 100% 66.0k/66.0k [00:01<00:00, 60.7kB/s, 6.41kB/s  ]
# data/train-00000-of-00001.parquet: reconstructing file: 100% 76.0k/76.0k [00:01<00:00, 69.9kB/s, 7.39kB/s  ]
# Generating train split: 100% 210/210 [00:00<00:00, 28715.00 examples/s]
# /content/urdu-question-generation/data/train.tsv: 75067 pairs
# /content/urdu-question-generation/data/valid.tsv: 10018 pairs
# /content/urdu-question-generation/data/wiki.tsv: 177 pairs

# %%
# !python -m scripts.train_tokenizer
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789228867.035436    7004 sentencepiece_trainer.cc:105] Starts training with :
# trainer_spec {
#   input: /content/urdu-question-generation/artifacts/tokenizer/sp_corpus.txt
#   input_format:
#   model_prefix: /content/urdu-question-generation/artifacts/tokenizer/ur_sp
#   model_type: UNIGRAM
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   user_defined_symbols: <ans>
#   user_defined_symbols: </ans>
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 1
#   bos_id: 2
#   eos_id: 3
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# I0000 00:00:1789228867.035718    7004 trainer_interface.cc:364] SentenceIterator is not specified. Using MultiFileSentenceIterator.
# I0000 00:00:1789228867.035778    7004 trainer_interface.cc:193] Loading corpus: /content/urdu-question-generation/artifacts/tokenizer/sp_corpus.txt
# I0000 00:00:1789228867.093647    7004 trainer_interface.cc:422] Loaded all 150134 sentences
# I0000 00:00:1789228867.093895    7004 trainer_interface.cc:440] Adding meta_piece: <pad>
# I0000 00:00:1789228867.093919    7004 trainer_interface.cc:440] Adding meta_piece: <unk>
# I0000 00:00:1789228867.093924    7004 trainer_interface.cc:440] Adding meta_piece: <s>
# I0000 00:00:1789228867.093928    7004 trainer_interface.cc:440] Adding meta_piece: </s>
# I0000 00:00:1789228867.093932    7004 trainer_interface.cc:440] Adding meta_piece: <ans>
# I0000 00:00:1789228867.093938    7004 trainer_interface.cc:440] Adding meta_piece: </ans>
# I0000 00:00:1789228867.093997    7004 trainer_interface.cc:445] Normalizing sentences...
# I0000 00:00:1789228868.993952    7004 trainer_interface.cc:555] all chars count=15225227
# I0000 00:00:1789228868.994204    7004 trainer_interface.cc:578] Alphabet size=766
# I0000 00:00:1789228868.994228    7004 trainer_interface.cc:579] Final character coverage=1
# I0000 00:00:1789228870.178273    7004 trainer_interface.cc:609] Done! preprocessed 150134 sentences.
# I0000 00:00:1789228871.596362    7004 unigram_model_trainer.cc:297] Making suffix array...
# I0000 00:00:1789228875.471136    7004 unigram_model_trainer.cc:301] Extracting frequent sub strings... node_num=8541571
# I0000 00:00:1789228896.676549    7004 unigram_model_trainer.cc:354] Initialized 179282 seed sentencepieces
# I0000 00:00:1789228896.891362    7004 trainer_interface.cc:615] Tokenizing input sentences with whitespace: 150134
# I0000 00:00:1789228897.218137    7004 trainer_interface.cc:626] Done! 75151
# I0000 00:00:1789228897.221517    7004 unigram_model_trainer.cc:628] Using 75151 sentences for EM training
# I0000 00:00:1789228897.810556    7004 unigram_model_trainer.cc:644] EM sub_iter=0 size=67863 obj=10.2197 num_tokens=3657278 num_tokens/piece=53.8921
# I0000 00:00:1789228898.282333    7004 unigram_model_trainer.cc:644] EM sub_iter=1 size=58141 obj=8.57868 num_tokens=3652218 num_tokens/piece=62.8166
# I0000 00:00:1789228899.332280    7004 unigram_model_trainer.cc:644] EM sub_iter=0 size=43597 obj=8.5409 num_tokens=3670471 num_tokens/piece=84.1909
# I0000 00:00:1789228899.744966    7004 unigram_model_trainer.cc:644] EM sub_iter=1 size=43588 obj=8.52933 num_tokens=3670741 num_tokens/piece=84.2145
# I0000 00:00:1789228900.727662    7004 unigram_model_trainer.cc:644] EM sub_iter=0 size=32691 obj=8.56964 num_tokens=3702443 num_tokens/piece=113.256
# I0000 00:00:1789228901.099027    7004 unigram_model_trainer.cc:644] EM sub_iter=1 size=32691 obj=8.52285 num_tokens=3702623 num_tokens/piece=113.261
# I0000 00:00:1789228901.931380    7004 unigram_model_trainer.cc:644] EM sub_iter=0 size=24518 obj=8.60537 num_tokens=3743325 num_tokens/piece=152.677
# I0000 00:00:1789228902.278136    7004 unigram_model_trainer.cc:644] EM sub_iter=1 size=24518 obj=8.59172 num_tokens=3743350 num_tokens/piece=152.678
# I0000 00:00:1789228903.039385    7004 unigram_model_trainer.cc:644] EM sub_iter=0 size=18388 obj=8.69111 num_tokens=3793499 num_tokens/piece=206.303
# I0000 00:00:1789228903.373363    7004 unigram_model_trainer.cc:644] EM sub_iter=1 size=18388 obj=8.67656 num_tokens=3793565 num_tokens/piece=206.307
# I0000 00:00:1789228904.065416    7004 unigram_model_trainer.cc:644] EM sub_iter=0 size=13791 obj=8.79465 num_tokens=3855341 num_tokens/piece=279.555
# I0000 00:00:1789228904.383986    7004 unigram_model_trainer.cc:644] EM sub_iter=1 size=13791 obj=8.77796 num_tokens=3855366 num_tokens/piece=279.557
# I0000 00:00:1789228905.021430    7004 unigram_model_trainer.cc:644] EM sub_iter=0 size=10343 obj=8.92123 num_tokens=3934339 num_tokens/piece=380.387
# I0000 00:00:1789228905.337364    7004 unigram_model_trainer.cc:644] EM sub_iter=1 size=10343 obj=8.89937 num_tokens=3934466 num_tokens/piece=380.399
# I0000 00:00:1789228905.958306    7004 unigram_model_trainer.cc:644] EM sub_iter=0 size=8800 obj=8.99352 num_tokens=3990928 num_tokens/piece=453.515
# I0000 00:00:1789228906.293735    7004 unigram_model_trainer.cc:644] EM sub_iter=1 size=8800 obj=8.9783 num_tokens=3991019 num_tokens/piece=453.525
# I0000 00:00:1789228906.301388    7004 trainer_interface.cc:702] Saving model: /content/urdu-question-generation/artifacts/tokenizer/ur_sp.model
# I0000 00:00:1789228906.309468    7004 trainer_interface.cc:714] Saving vocabs: /content/urdu-question-generation/artifacts/tokenizer/ur_sp.vocab

# %%
# !python -m scripts.train
# Out:
# Epoch 1/15
# Train Loss: 5.2050 | Valid Loss: 7.1556
# Best model saved with loss: 7.1556
# Epoch 2/15
# Train Loss: 4.4141 | Valid Loss: 6.9608
# Best model saved with loss: 6.9608
# Epoch 3/15
# Train Loss: 4.0990 | Valid Loss: 6.8835
# Best model saved with loss: 6.8835
# Epoch 4/15
# Train Loss: 3.7475 | Valid Loss: 6.7455
# Best model saved with loss: 6.7455
# Epoch 5/15
# Train Loss: 3.4768 | Valid Loss: 6.5471
# Best model saved with loss: 6.5471
# Epoch 6/15
# Train Loss: 3.3413 | Valid Loss: 6.5090
# Best model saved with loss: 6.5090
# Epoch 7/15
# Train Loss: 3.2927 | Valid Loss: 6.5195
# Epoch 8/15
# Train Loss: 3.2842 | Valid Loss: 6.3290
# Best model saved with loss: 6.3290
# Epoch 9/15
# Train Loss: 3.3160 | Valid Loss: 6.2670
# Best model saved with loss: 6.2670
# Epoch 10/15
# Train Loss: 3.3137 | Valid Loss: 6.1451
# Best model saved with loss: 6.1451
# Epoch 11/15
# Train Loss: 3.3450 | Valid Loss: 5.9215
# Best model saved with loss: 5.9215
# Epoch 12/15
# Train Loss: 3.3774 | Valid Loss: 5.9454
# Epoch 13/15
# Train Loss: 3.4167 | Valid Loss: 5.9002
# Best model saved with loss: 5.9002
# Epoch 14/15
# Train Loss: 3.4710 | Valid Loss: 5.7973
# Best model saved with loss: 5.7973
# Epoch 15/15
# Train Loss: 3.5044 | Valid Loss: 5.7141
# Best model saved with loss: 5.7141

# %%
# !python -m scripts.evaluation
# Out:
# /content/urdu-question-generation/scripts/evaluation.py:206: UserWarning: Glyph 1729 (\N{ARABIC LETTER HEH GOAL}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /content/urdu-question-generation/scripts/evaluation.py:206: UserWarning: Matplotlib currently does not support Arabic natively.
#   fig.tight_layout()
# /content/urdu-question-generation/scripts/evaluation.py:206: UserWarning: Glyph 1746 (\N{ARABIC LETTER YEH BARREE}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /content/urdu-question-generation/scripts/evaluation.py:206: UserWarning: Glyph 1748 (\N{ARABIC FULL STOP}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# /content/urdu-question-generation/scripts/evaluation.py:207: UserWarning: Glyph 1729 (\N{ARABIC LETTER HEH GOAL}) missing from font(s) DejaVu Sans.
#   fig.savefig(FIGS_DIR / "attention_heatmap.png")
# /content/urdu-question-generation/scripts/evaluation.py:207: UserWarning: Matplotlib currently does not support Arabic natively.
#   fig.savefig(FIGS_DIR / "attention_heatmap.png")
# /content/urdu-question-generation/scripts/evaluation.py:207: UserWarning: Glyph 1746 (\N{ARABIC LETTER YEH BARREE}) missing from font(s) DejaVu Sans.
#   fig.savefig(FIGS_DIR / "attention_heatmap.png")
# /content/urdu-question-generation/scripts/evaluation.py:207: UserWarning: Glyph 1748 (\N{ARABIC FULL STOP}) missing from font(s) DejaVu Sans.
#   fig.savefig(FIGS_DIR / "attention_heatmap.png")
