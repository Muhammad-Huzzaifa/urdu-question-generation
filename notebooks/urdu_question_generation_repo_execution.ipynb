# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-Huzzaifa/urdu-question-generation/blob/main/notebooks/urdu_question_generation_repo_execution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata

TOKEN = userdata.get('GITHUB_TOKEN')

USERNAME = "Muhammad-Huzzaifa"
REPO_NAME = "urdu-question-generation"

REPO_URL = f"https://{USERNAME}:{TOKEN}@github.com/{USERNAME}/{REPO_NAME}.git"

# %%
# !git clone {REPO_URL}
# Out:
# Cloning into 'urdu-question-generation'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 41 (delta 10), reused 34 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (41/41), 140.30 KiB | 1.92 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
# %cd {REPO_NAME}
# Out:
# /content/urdu-question-generation

# %%
# !git config --global user.email "huzzaaifa83@gmail.com"
# !git config --global user.name "Muhammad Huzaifa"

# %%
# !git pull origin main
# Out:
# From https://github.com/Muhammad-Huzzaifa/urdu-question-generation
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.6/129.6 kB 7.2 MB/s eta 0:00:00
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24986 sha256=d2b87c4b09d720c10e3b72c46b70cd2ffc050b173794bc6d214164fbf6aa99ef
#   Stored in directory: /root/.cache/pip/wheels/44/af/da/5ffc433e2786f0b1a9c6f458d5fb8f611d8eb332387f18698f
# Successfully built rouge-score
# ...

# %%
# !python -m scripts.prepare_data
# Out:
# README.md: 100% 898/898 [00:00<00:00, 2.31MB/s]
# ...
#
# data/train-00000-of-00001-bac007e8ca7192(…): downloading bytes:  73% 22.0M/30.2M [00:00<00:00, 42.4MB/s, 1.03MB/s  ]
# data/train-00000-of-00001-bac007e8ca7192(…): downloading bytes: 100% 27.9M/27.9M [00:00<00:00, 35.4MB/s, 2.71MB/s  ]
# data/train-00000-of-00001-bac007e8ca7192(…): reconstructing file: 100% 30.2M/30.2M [00:00<00:00, 38.4MB/s, 2.96MB/s  ]
#
# data/validation-00000-of-00001-cf8a6960d(…): downloading bytes:   0% 0.00/2.92M [00:00<?, ?B/s]
# data/validation-00000-of-00001-cf8a6960d(…): downloading bytes: 100% 2.56M/2.56M [00:00<00:00, 6.35MB/s,  253kB/s  ]
# data/validation-00000-of-00001-cf8a6960d(…): reconstructing file: 100% 2.92M/2.92M [00:00<00:00, 7.26MB/s,  290kB/s  ]
# Generating train split: 100% 124745/124745 [00:00<00:00, 186786.62 examples/s]
# Generating validation split: 100% 16824/16824 [00:00<00:00, 154898.90 examples/s]
# DatasetDict({
#     train: Dataset({
# ...

# %%
# !python -m scripts.train_tokenizer
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789127618.505042    1938 sentencepiece_trainer.cc:105] Starts training with :
# trainer_spec {
#   input: /content/urdu-question-generation/artifacts/tokenizer/sp_corpus.txt
#   input_format:
#   model_prefix: /content/urdu-question-generation/artifacts/tokenizer/ur_sp
#   model_type: UNIGRAM
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   user_defined_symbols: <ans>
#   user_defined_symbols: </ans>
#   required_chars:
# ...
